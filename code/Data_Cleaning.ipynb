# %%
import json
import sys
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
df_fp_ny = pd.read_csv('../database/Film Production_NYC_database.csv') 
df_fp_la = pd.read_csv('../database/Film Production_Los Angeles_database.csv')
df_fp_ga = pd.read_csv('../database/Film Production_Atlanta_database.csv')

# %% [markdown]
# # Data Cleaning

# %%
df_fp_ny.loc[(df_fp_ny['Rating'] == 1.5)]
# Out:
#                          Name                                  Address  \
# 282                  Spectrum   ['43 W 23rd St', 'New York, NY 10010']
# 283  Pure Productive Services                  ['Weehawken, NJ 07086']
# 285               Elen's Kids   ['1119 Raritan Rd', 'Clark, NJ 07066']
# 290                  Spectrum  ['2554 Broadway', 'New York, NY 10025']
#
#           City  Rating  Review Count  \
# 282   New York     1.5           891
# 283  Weehawken     1.5            67
# 285      Clark     1.5            21
# 290   New York     1.5           162
#
#                                            Coordinates  Price  \
# 282  {'latitude': 40.7425261, 'longitude': -73.9911...    NaN
# 283  {'latitude': 40.774097442627, 'longitude': -74...    NaN
# 285   {'latitude': 40.628659, 'longitude': -74.312986}    NaN
# 290  {'latitude': 40.79442064420939, 'longitude': -...    NaN
#
#                          Id  \
# 282  8AdJC2-2VboPN_Wp8oTddw
# 283  g-0ipgPROCVf56c3n0mkEg
# 285  BaCGJ5iiVulv_Ap48DYvdw
# 290  HUTQ51a22NsFOI7JcFNm-Q
#
#                                             Categories   Latitude  Longitude
# 282  [{'alias': 'televisionserviceproviders', 'titl...  40.742526 -73.991140
# 283  [{'alias': 'homecleaning', 'title': 'Home Clea...  40.774097 -74.017487
# 285  [{'alias': 'talentagencies', 'title': 'Talent ...  40.628659 -74.312986
# 290  [{'alias': 'televisionserviceproviders', 'titl...  40.794421 -73.971641

# %% [markdown]
# Above is a good example of why it is necessary to clean our data. As you can see, NY has a shocking disproportion of review counts for low-rated companies. This was worthy of closer inspection, and as we can see the companies with a 1.5 rating that weighing our data so heavily in this category are not only **NOT** film production companies, it's two locations for the same company!
#
# The *reason* that this company has such a high review count compared to the companies that we are actually interested in, is that it is a company that provides a consumer service to a wide customer base (a public utility that is essentially used by everyone in this location). The companies that we are interested in provide a niche service *to other companies and professionals in the industry*, which will of course be a smaller sample of the wider populace of New York!

# %%
df_fp_ny.loc[(df_fp_ny['Rating'] == 1)]
# Out:
#                                                Name  \
# 113                     Professional Sound Services
# 121                              Adiuvo Productions
# 136                              360 Sound & Vision
# 181                               Art Contra Studio
# 185               Picture Perfect Media Productions
# 197                    Lights Camera Action Studios
# 206                               Shaved Head Media
# 216                                WhiteWater Music
# 225                                NYC Printing 123
# 234                          Big City Manufacturing
# 240                                  Fiorella Image
# 252              Visual Image Video and Photography
# 267  The New York Talent Club Talent & Model Agency
# 269                                 Marc Trautrimas
# 278                 Videoccasions Video Productions
# 286                                       Moviepass
# 288                               Verizon Corporate
# 296                        Jordan Green Productions
#
#                                                Address            City  \
# 113  ['311 W 43rd St', 'Ste 1100', 'Manhattan, NY 1...       Manhattan
# 121            ['95 Horatio St', 'New York, NY 10014']        New York
# 136              ['330 7th Ave', 'New York, NY 10001']        New York
# 181                             ['Cranford, NJ 07107']        Cranford
# 185               ['95 Parker St', 'Newark, NJ 07104']          Newark
# 197  ['1674 Broadway', 'Ste 802', 'Manhattan, NY 10...       Manhattan
# 206                             ['Brooklyn, NY 11221']        Brooklyn
# 216       ['5 E19th St', 'Fl 3', 'New York, NY 10003']        New York
# 225              ['436 4th Ave', 'Brooklyn, NY 11215']        Brooklyn
# 234  ['2321 Jfk Boulevard', 'Sb 27-A', 'North Berge...    North Bergen
# 240                            ['Edgewater, NJ 07020']       Edgewater
# 252        ['18 Hervey St', 'Staten Island, NY 10309']   Staten Island
# 267                             ['New York, NY 10001']        New York
# 269    ['1198 Metropolitan Ave', 'Brooklyn, NY 11237']        Brooklyn
# 278  ['808 High Mountain Rd', 'Ste 207', 'Franklin ...  Franklin Lakes
# 286  ['175 Varick St', 'Ste 604', 'New York, NY 100...        New York
# 288              ['140 West St', 'New York, NY 10007']        New York
# 296         ['3502 Leavenworth St', 'Omaha, NE 68105']           Omaha
#
#      Rating  Review Count                                        Coordinates  \
# 113     1.0             1  {'latitude': 40.7584496, 'longitude': -73.9899...
# 121     1.0             2  {'latitude': 40.7984185256138, 'longitude': -7...
# 136     1.0             1  {'latitude': 40.7477397, 'longitude': -73.9933...
# 181     1.0             1   {'latitude': 40.760441, 'longitude': -74.188745}
# 185     1.0             1   {'latitude': 40.755977, 'longitude': -74.179046}
# 197     1.0             9     {'latitude': 40.76279, 'longitude': -73.98294}
# 206     1.0             1      {'latitude': 40.6924, 'longitude': -73.92621}
# 216     1.0             3  {'latitude': 40.7327412957708, 'longitude': -7...
# 225     1.0            17  {'latitude': 40.6708653, 'longitude': -73.9886...
# 234     1.0             2   {'latitude': 40.770339, 'longitude': -74.038849}
# 240     1.0             1  {'latitude': 40.8236770629883, 'longitude': -7...
# 252     1.0             2  {'latitude': 40.5533063, 'longitude': -74.2169...
# 267     1.0             1  {'latitude': 40.750244140625, 'longitude': -73...
# 269     1.0             6   {'latitude': 40.713945, 'longitude': -73.929049}
# 278     1.0             8   {'latitude': 40.994272, 'longitude': -74.213135}
# 286     1.0           100  {'latitude': 40.7274061338494, 'longitude': -7...
# 288     1.0           253  {'latitude': 40.7138062516244, 'longitude': -7...
# 296     1.0             1   {'latitude': 41.252651, 'longitude': -95.964111}
#
#      Price                      Id  \
# 113    NaN  kNolL6khB1nhB6iGw6gXTg
# 121    NaN  tX-kGQ_NzaUtRRpAKUOwtg
# 136    NaN  phBGfDXgCvmZAtSYvo6A4Q
# 181    NaN  9-Jo6kltXxyd4XJuyJElGQ
# 185    NaN  XIYaAtD9Hmm86edDPgdLXw
# 197    NaN  CY5xxJJC9I4AyKZbuMQL2g
# 206    NaN  ZIrbAbsHyd9SaL2cSrX9Qw
# 216    NaN  NgIHKwjOe0nJeCIGcNIPwQ
# 225    NaN  G-aDtjxQSPTgt9pRQXKY_Q
# 234    NaN  8gOeYfV1G1raGQi-EtKhTA
# 240    NaN  hEkCCGLEQFdDlcWhsErxMQ
# 252    NaN  nECtyzKpkRYl33uz-HdMEg
# 267    NaN  5gvvuJ3_cBsdmb_GQ8yjFg
# 269    NaN  6Z91hfdQR_OK0S8dZHvoTg
# 278    NaN  3qp8Yi2YkdEQoeno_aKKGg
# 286    NaN  l-tLojHCnrhR3zGC9ER47g
# 288    4.0  PRy3uF0eWQReOnByXWpJuQ
# 296    NaN  gseNJEdRFVKwgt_FqK5SCw
#
#                                             Categories   Latitude  Longitude
# 113  [{'alias': 'electronics', 'title': 'Electronic...  40.758450 -73.989983
# 121  [{'alias': 'videofilmproductions', 'title': 'V...  40.798419 -73.961374
# 136  [{'alias': 'videofilmproductions', 'title': 'V...  40.747740 -73.993374
# 181  [{'alias': 'videofilmproductions', 'title': 'V...  40.760441 -74.188745
# 185  [{'alias': 'videographers', 'title': 'Videogra...  40.755977 -74.179046
# 197  [{'alias': 'videofilmproductions', 'title': 'V...  40.762790 -73.982940
# 206  [{'alias': 'advertising', 'title': 'Advertisin...  40.692400 -73.926210
# 216  [{'alias': 'musicproduction', 'title': 'Music ...  40.732741 -73.987368
# 225  [{'alias': 'web_design', 'title': 'Web Design'...  40.670865 -73.988632
# 234  [{'alias': 'graphicdesign', 'title': 'Graphic ...  40.770339 -74.038849
# 240  [{'alias': 'eventphotography', 'title': 'Event...  40.823677 -73.973816
# 252  [{'alias': 'videographers', 'title': 'Videogra...  40.553306 -74.216993
# 267  [{'alias': 'talentagencies', 'title': 'Talent ...  40.750244 -73.997025
# 269   [{'alias': 'architects', 'title': 'Architects'}]  40.713945 -73.929049
# 278  [{'alias': 'videographers', 'title': 'Videogra...  40.994272 -74.213135
# 286  [{'alias': 'isps', 'title': 'Internet Service ...  40.727406 -74.006050
# 288  [{'alias': 'mobilephones', 'title': 'Mobile Ph...  40.713806 -74.012984
# 296  [{'alias': 'videofilmproductions', 'title': 'V...  41.252651 -95.964111

# %% [markdown]
# The 1.0 rated companies on Yelp offer a better representation of companies that match our desired results, though here too we can see some listings that we may want to remove (*Marc Trautrimas: architects, Moviepass: isps, Verizon Corporate: mobilephones).
#
# Other examples here are not entirely dedicated to the film or television production industry, but certainly may offer parallel services (see under categories: *event photography, talentagencies, music production, advertising, graphicdesign, electronics* (i.e.- camera and sound equipment) *etc*.
#
# Knowing that such companies may offer products or services that would compete with services that we offer, they would be useful to keep. The others, we will get rid of so that we may work with a more representative dataset.

# %% [markdown]
# #### Let's set the dataframe to only include rows where the company name is not 'Spectrum'

# %%
df_fp_ny = df_fp_ny.loc[(df_fp_ny['Name'] != 'Spectrum')]

# %%
df_fp_ny.loc[(df_fp_ny['Rating'] == 1.5)] # Checking and confirming that it is gone
# Out:
#                          Name                                 Address  \
# 283  Pure Productive Services                 ['Weehawken, NJ 07086']
# 285               Elen's Kids  ['1119 Raritan Rd', 'Clark, NJ 07066']
#
#           City  Rating  Review Count  \
# 283  Weehawken     1.5            67
# 285      Clark     1.5            21
#
#                                            Coordinates  Price  \
# 283  {'latitude': 40.774097442627, 'longitude': -74...    NaN
# 285   {'latitude': 40.628659, 'longitude': -74.312986}    NaN
#
#                          Id  \
# 283  g-0ipgPROCVf56c3n0mkEg
# 285  BaCGJ5iiVulv_Ap48DYvdw
#
#                                             Categories   Latitude  Longitude
# 283  [{'alias': 'homecleaning', 'title': 'Home Clea...  40.774097 -74.017487
# 285  [{'alias': 'talentagencies', 'title': 'Talent ...  40.628659 -74.312986

# %% [markdown]
# Next, let's get rid of homecleaning, and the other irrelevent categories mentioned above, while we're at it setting dataframe to only be data that does not contain 'homecleaning' in its categories

# %%
df_fp_ny = df_fp_ny.loc[(df_fp_ny['Categories'].str.contains('homecleaning') == False)]
df_fp_ny.loc[(df_fp_ny['Categories'].str.contains('homecleaning') == True)] # no homecleaning returned
# Out:
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price, Id, Categories, Latitude, Longitude]
# Index: []

# %%
# setting dataframe to only be data that does not contain 'mobilephones' or 'architects' in its categories
df_fp_ny = df_fp_ny.loc[(df_fp_ny['Categories'].str.contains('mobilephones') == False) & (df_fp_ny['Categories'].str.contains('architects') == False)]
df_fp_ny.loc[(df_fp_ny['Categories'].str.contains('mobilephones') == True)] # using .loc, we can isolate multiple contents in 'Categories'
# Out:
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price, Id, Categories, Latitude, Longitude]
# Index: []

# %% [markdown]
# Another note on cleaning... when searching for when a cell contains a string, be careful not to accidentally cut off another word. A good example below: 'isps' seems like it could be in many other words, such as 'crisps' were we dealing with data on food items, or 'lispro' when dealing with data related to medicine.<br>
# Fortunately, in this instance, 'isps' does not hit any other data.

# %%
df_fp_ny.loc[(df_fp_ny['Categories'].str.contains('isps') == True)] # checks out ok
df_fp_ny = df_fp_ny.loc[(df_fp_ny['Categories'].str.contains('isps') == False)]

# %%
df_fp_ny['Categories'].unique() # checking unique items in categories to see if we can find some more undesirable results.
# Out:
# array(["[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'theater', 'title': 'Performing Arts'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'costumes', 'title': 'Costumes'}, {'alias': 'props', 'title': 'Props'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'studiotaping', 'title': 'Studio Taping'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'audiovisualequipmentrental', 'title': 'Audio/Visual Equipment Rental'}, {'alias': 'machinerental', 'title': 'Machine & Tool Rental'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'artspacerentals', 'title': 'Art Space Rentals'}]",
#        "[{'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'studiotaping', 'title': 'Studio Taping'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'artschools', 'title': 'Art Schools'}, {'alias': 'theater', 'title': 'Performing Arts'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}]",
#        "[{'alias': 'movietheaters', 'title': 'Cinema'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'signmaking', 'title': 'Signmaking'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'lighting', 'title': 'Lighting Fixtures & Equipment'}]",
#        "[{'alias': 'adultedu', 'title': 'Adult Education'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'theater', 'title': 'Performing Arts'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'nonprofit', 'title': 'Community Service/Non-Profit'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'hifi', 'title': 'High Fidelity Audio Equipment'}]",
#        "[{'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'adultedu', 'title': 'Adult Education'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'artspacerentals', 'title': 'Art Space Rentals'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'datarecovery', 'title': 'Data Recovery'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]",
#        "[{'alias': 'theater', 'title': 'Performing Arts'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'galleries', 'title': 'Art Galleries'}]",
#        "[{'alias': 'electronics', 'title': 'Electronics'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'artspacerentals', 'title': 'Art Space Rentals'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'theater', 'title': 'Performing Arts'}, {'alias': 'educationservices', 'title': 'Educational Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'editorialservices', 'title': 'Editorial Services'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'publicrelations', 'title': 'Public Relations'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'screen_printing_tshirt_printing', 'title': 'Screen Printing/T-Shirt Printing'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'artspacerentals', 'title': 'Art Space Rentals'}]",
#        "[{'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'talentagencies', 'title': 'Talent Agencies'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'wedding_planning', 'title': 'Wedding Planning'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'bookbinding', 'title': 'Bookbinding'}]",
#        "[{'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'printmedia', 'title': 'Print Media'}]",
#        "[{'alias': 'businessconsulting', 'title': 'Business Consulting'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'publicrelations', 'title': 'Public Relations'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicians', 'title': 'Musicians'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'screen_printing_tshirt_printing', 'title': 'Screen Printing/T-Shirt Printing'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'translationservices', 'title': 'Translation Services'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'wholesale_stores', 'title': 'Wholesale Stores'}, {'alias': 'kitchenandbath', 'title': 'Kitchen & Bath'}, {'alias': 'suppliesrestaurant', 'title': 'Restaurant Supplies'}]",
#        "[{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'signmaking', 'title': 'Signmaking'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'artrestoration', 'title': 'Art Restoration'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'partyequipmentrentals', 'title': 'Party Equipment Rentals'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'signmaking', 'title': 'Signmaking'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'djs', 'title': 'DJs'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'publicrelations', 'title': 'Public Relations'}]",
#        "[{'alias': 'screen_printing_tshirt_printing', 'title': 'Screen Printing/T-Shirt Printing'}, {'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'officecleaning', 'title': 'Office Cleaning'}, {'alias': 'damagerestoration', 'title': 'Damage Restoration'}, {'alias': 'pressurewashers', 'title': 'Pressure Washers'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'signmaking', 'title': 'Signmaking'}, {'alias': 'bookbinding', 'title': 'Bookbinding'}]",
#        "[{'alias': 'commissionedartists', 'title': 'Commissioned Artists'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'framing', 'title': 'Framing'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'entertainmentlaw', 'title': 'Entertainment Law'}]",
#        "[{'alias': 'djs', 'title': 'DJs'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventplanning', 'title': 'Party & Event Planning'}]",
#        "[{'alias': 'legalservices', 'title': 'Legal Services'}, {'alias': 'businesslawyers', 'title': 'Business Law'}]",
#        "[{'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'employmentlawyers', 'title': 'Employment Law'}, {'alias': 'businesslawyers', 'title': 'Business Law'}, {'alias': 'entertainmentlaw', 'title': 'Entertainment Law'}]",
#        "[{'alias': 'signmaking', 'title': 'Signmaking'}, {'alias': 'tvmounting', 'title': 'TV Mounting'}, {'alias': 'metalfabricators', 'title': 'Metal Fabricators'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'copyshops', 'title': 'Printing Services'}]",
#        "[{'alias': 'lifecoach', 'title': 'Life Coach'}, {'alias': 'reiki', 'title': 'Reiki'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        '[]',
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}]",
#        "[{'alias': 'lifecoach', 'title': 'Life Coach'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'signmaking', 'title': 'Signmaking'}, {'alias': 'vehiclewraps', 'title': 'Vehicle Wraps'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'personal_shopping', 'title': 'Personal Shopping'}, {'alias': 'businessconsulting', 'title': 'Business Consulting'}]",
#        "[{'alias': 'careercounseling', 'title': 'Career Counseling'}]",
#        "[{'alias': 'signmaking', 'title': 'Signmaking'}]",
#        "[{'alias': 'bartenders', 'title': 'Bartenders'}, {'alias': 'employmentagencies', 'title': 'Employment Agencies'}, {'alias': 'talentagencies', 'title': 'Talent Agencies'}]",
#        "[{'alias': 'talentagencies', 'title': 'Talent Agencies'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'signmaking', 'title': 'Signmaking'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'shipping_centers', 'title': 'Shipping Centers'}, {'alias': 'signmaking', 'title': 'Signmaking'}]",
#        "[{'alias': 'employmentagencies', 'title': 'Employment Agencies'}]",
#        "[{'alias': 'shipping_centers', 'title': 'Shipping Centers'}, {'alias': 'copyshops', 'title': 'Printing Services'}, {'alias': 'signmaking', 'title': 'Signmaking'}]",
#        "[{'alias': 'privateinvestigation', 'title': 'Private Investigation'}, {'alias': 'security', 'title': 'Security Services'}]",
#        "[{'alias': 'autoglass', 'title': 'Auto Glass Services'}, {'alias': 'signmaking', 'title': 'Signmaking'}, {'alias': 'homewindowtinting', 'title': 'Home Window Tinting'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]"],
#       dtype=object)

# %%
# Now, let's remove a whole bunch more...
df_fp_ny = df_fp_ny.loc[(df_fp_ny['Categories'].str.contains('copyshops') == False) 
                        & (df_fp_ny['Categories'].str.contains('nonprofit') == False) 
                        & (df_fp_ny['Categories'].str.contains('movietheaters') == False) 
                        & (df_fp_ny['Categories'].str.contains('venues') == False) 
                        & (df_fp_ny['Categories'].str.contains('galleries') == False) 
                        & (df_fp_ny['Categories'].str.contains('artspacerentals') == False) 
                        & (df_fp_ny['Categories'].str.contains('publicrelations') == False) 
                        & (df_fp_ny['Categories'].str.contains('wholesale_stores') == False) 
                        & (df_fp_ny['Categories'].str.contains('suppliesrestaurant') == False) 
                        & (df_fp_ny['Categories'].str.contains('legalservices') == False) 
                        & (df_fp_ny['Categories'].str.contains('lifecoach') == False) 
                        & (df_fp_ny['Categories'].str.contains('signmaking') == False)  
                        & (df_fp_ny['Categories'].str.contains('entertainmentlaw') == False) 
                        & (df_fp_ny['Categories'].str.contains('personal_shopping') == False) 
                        & (df_fp_ny['Categories'].str.contains('careercounseling') == False) 
                        & (df_fp_ny['Categories'].str.contains('bartenders') == False) 
                        & (df_fp_ny['Categories'].str.contains('privateinvestigation') == False) 
                        & (df_fp_ny['Categories'].str.contains('autoglass') == False)
                       ]

# %%
df_fp_la = df_fp_la.loc[(df_fp_la['Categories'].str.contains('copyshops') == False) 
                        & (df_fp_la['Categories'].str.contains('nonprofit') == False) 
                        & (df_fp_la['Categories'].str.contains('movietheaters') == False) 
                        & (df_fp_la['Categories'].str.contains('venues') == False) 
                        & (df_fp_la['Categories'].str.contains('galleries') == False) 
                        & (df_fp_la['Categories'].str.contains('artspacerentals') == False) 
                        & (df_fp_la['Categories'].str.contains('publicrelations') == False) 
                        & (df_fp_la['Categories'].str.contains('wholesale_stores') == False) 
                        & (df_fp_la['Categories'].str.contains('suppliesrestaurant') == False) 
                        & (df_fp_la['Categories'].str.contains('legalservices') == False) 
                        & (df_fp_la['Categories'].str.contains('lifecoach') == False) 
                        & (df_fp_la['Categories'].str.contains('signmaking') == False)  
                        & (df_fp_la['Categories'].str.contains('entertainmentlaw') == False) 
                        & (df_fp_la['Categories'].str.contains('personal_shopping') == False) 
                        & (df_fp_la['Categories'].str.contains('careercounseling') == False) 
                        & (df_fp_la['Categories'].str.contains('bartenders') == False) 
                        & (df_fp_la['Categories'].str.contains('privateinvestigation') == False) 
                        & (df_fp_la['Categories'].str.contains('autoglass') == False)
                        & (df_fp_la['Categories'].str.contains('mobilephones') == False) 
                        & (df_fp_la['Categories'].str.contains('isps') == False) 
                        & (df_fp_la['Categories'].str.contains('homecleaning') == False) 
                        & (df_fp_la['Categories'].str.contains('architects') == False)
                        & (df_fp_la['Categories'].str.contains('computers') == False) 
                        & (df_fp_la['Categories'].str.contains('couriers') == False) 
                        & (df_fp_la['Categories'].str.contains('dramaschools') == False) 
                        & (df_fp_la['Categories'].str.contains('wedding_planning') == False)
                        & (df_fp_la['Categories'].str.contains('gourmet') == False) 
                        & (df_fp_la['Categories'].str.contains('hobbyshops') == False) 
                        & (df_fp_la['Categories'].str.contains('security') == False)
                        & (df_fp_la['Categories'].str.contains('itservices') == False) 
                        & (df_fp_la['Categories'].str.contains('businessconsulting') == False) 
                        & (df_fp_la['Categories'].str.contains('businesslawyers') == False) 
                        & (df_fp_la['Categories'].str.contains('framing') == False)
                       ]

# %%
df_fp_la = df_fp_la.loc[(df_fp_la['Name'] != 'DVD Your Memories')] 
df_fp_la = df_fp_la.loc[(df_fp_la['Name'] != 'Nick Metropolis Collectible Furniture')] 
df_fp_la = df_fp_la.loc[(df_fp_la['Name'] != 'Take Sessions')] 
df_fp_la = df_fp_la.loc[(df_fp_la['Name'] != 'Nick Metropolis Collectible Furniture')]

# %%
df_fp_ga = df_fp_ga.loc[(df_fp_ga['Categories'].str.contains('copyshops') == False) 
                        & (df_fp_ga['Categories'].str.contains('nonprofit') == False) 
                        & (df_fp_ga['Categories'].str.contains('movietheaters') == False) 
                        & (df_fp_ga['Categories'].str.contains('venues') == False) 
                        & (df_fp_ga['Categories'].str.contains('galleries') == False) 
                        & (df_fp_ga['Categories'].str.contains('artspacerentals') == False) 
                        & (df_fp_ga['Categories'].str.contains('publicrelations') == False) 
                        & (df_fp_ga['Categories'].str.contains('wholesale_stores') == False) 
                        & (df_fp_ga['Categories'].str.contains('suppliesrestaurant') == False) 
                        & (df_fp_ga['Categories'].str.contains('legalservices') == False) 
                        & (df_fp_ga['Categories'].str.contains('lifecoach') == False) 
                        & (df_fp_ga['Categories'].str.contains('signmaking') == False)  
                        & (df_fp_ga['Categories'].str.contains('entertainmentlaw') == False) 
                        & (df_fp_ga['Categories'].str.contains('personal_shopping') == False) 
                        & (df_fp_ga['Categories'].str.contains('careercounseling') == False) 
                        & (df_fp_ga['Categories'].str.contains('bartenders') == False) 
                        & (df_fp_ga['Categories'].str.contains('privateinvestigation') == False) 
                        & (df_fp_ga['Categories'].str.contains('autoglass') == False)
                        & (df_fp_ga['Categories'].str.contains('mobilephones') == False) 
                        & (df_fp_ga['Categories'].str.contains('isps') == False) 
                        & (df_fp_ga['Categories'].str.contains('homecleaning') == False) 
                        & (df_fp_ga['Categories'].str.contains('architects') == False) 
                        & (df_fp_ga['Categories'].str.contains('computers') == False) 
                        & (df_fp_ga['Categories'].str.contains('couriers') == False) 
                        & (df_fp_ga['Categories'].str.contains('dramaschools') == False) 
                        & (df_fp_ga['Categories'].str.contains('wedding_planning') == False)
                        & (df_fp_ga['Categories'].str.contains('gourmet') == False) 
                        & (df_fp_ga['Categories'].str.contains('hobbyshops') == False) 
                        & (df_fp_ga['Categories'].str.contains('security') == False)
                        & (df_fp_ga['Categories'].str.contains('itservices') == False) 
                        & (df_fp_ga['Categories'].str.contains('businessconsulting') == False) 
                        & (df_fp_ga['Categories'].str.contains('businesslawyers') == False) 
                        & (df_fp_ga['Categories'].str.contains('framing') == False)
                        & (df_fp_ga['Categories'].str.contains('musicians') == False)
                       ] # if somebody knows how to make code cells collapsible in Jupyter Notebooks, please let Mike know

# %% [markdown]
# We use the .unique() method to give these a glance and ensure that remaining categories look relevant to film, television, and/or media production

# %%
df_fp_la['Categories'].unique()
# Out:
# array(["[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}, {'alias': 'audiovisualequipmentrental', 'title': 'Audio/Visual Equipment Rental'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'dance_schools', 'title': 'Dance Schools'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'artschools', 'title': 'Art Schools'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}, {'alias': 'duplicationservices', 'title': 'Duplication Services'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'djs', 'title': 'DJs'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'arts', 'title': 'Arts & Entertainment'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sharedofficespaces', 'title': 'Shared Office Spaces'}]",
#        "[{'alias': 'massmedia', 'title': 'Mass Media'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'duplicationservices', 'title': 'Duplication Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'specialtyschools', 'title': 'Specialty Schools'}]",
#        "[{'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'duplicationservices', 'title': 'Duplication Services'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'editorialservices', 'title': 'Editorial Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'massmedia', 'title': 'Mass Media'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'studiotaping', 'title': 'Studio Taping'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'theater', 'title': 'Performing Arts'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}]",
#        "[{'alias': 'televisionstations', 'title': 'Television Stations'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'duplicationservices', 'title': 'Duplication Services'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'audiovisualequipmentrental', 'title': 'Audio/Visual Equipment Rental'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'djs', 'title': 'DJs'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'theater', 'title': 'Performing Arts'}, {'alias': 'artschools', 'title': 'Art Schools'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'editorialservices', 'title': 'Editorial Services'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'talentagencies', 'title': 'Talent Agencies'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'theater', 'title': 'Performing Arts'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'djs', 'title': 'DJs'}]",
#        "[{'alias': 'musicvideo', 'title': 'Music & DVDs'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'theater', 'title': 'Performing Arts'}, {'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'lighting', 'title': 'Lighting Fixtures & Equipment'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'audiovisualequipmentrental', 'title': 'Audio/Visual Equipment Rental'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'lightingstores', 'title': 'Lighting Stores'}]",
#        "[{'alias': 'travelservices', 'title': 'Travel Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'adultedu', 'title': 'Adult Education'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'studiotaping', 'title': 'Studio Taping'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'photoclasses', 'title': 'Photography Classes'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'editorialservices', 'title': 'Editorial Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'audiovisualequipmentrental', 'title': 'Audio/Visual Equipment Rental'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}, {'alias': 'duplicationservices', 'title': 'Duplication Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'props', 'title': 'Props'}]",
#        "[{'alias': 'sewingalterations', 'title': 'Sewing & Alterations'}, {'alias': 'productdesign', 'title': 'Product Design'}, {'alias': 'bridal', 'title': 'Bridal'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'duplicationservices', 'title': 'Duplication Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'studiotaping', 'title': 'Studio Taping'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'virtualrealitycenters', 'title': 'Virtual Reality Centers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'homewindowtinting', 'title': 'Home Window Tinting'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'digitizingservices', 'title': 'Digitizing Services'}, {'alias': 'duplicationservices', 'title': 'Duplication Services'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'editorialservices', 'title': 'Editorial Services'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'educationservices', 'title': 'Educational Services'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'makeupartists', 'title': 'Makeup Artists'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'commissionedartists', 'title': 'Commissioned Artists'}]",
#        "[{'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'specialtyschools', 'title': 'Specialty Schools'}]",
#        "[{'alias': 'notaries', 'title': 'Notaries'}, {'alias': 'taxservices', 'title': 'Tax Services'}, {'alias': 'professional', 'title': 'Professional Services'}]",
#        "[{'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'softwaredevelopment', 'title': 'Software Development'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicians', 'title': 'Musicians'}]",
#        "[{'alias': 'musicians', 'title': 'Musicians'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'talentagencies', 'title': 'Talent Agencies'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'summer_camps', 'title': 'Summer Camps'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'taxservices', 'title': 'Tax Services'}, {'alias': 'accountants', 'title': 'Accountants'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'custommerchandise', 'title': 'Customized Merchandise'}, {'alias': 'duplicationservices', 'title': 'Duplication Services'}, {'alias': 'screen_printing_tshirt_printing', 'title': 'Screen Printing/T-Shirt Printing'}]",
#        "[{'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'eventplanning', 'title': 'Party & Event Planning'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'doulas', 'title': 'Doulas'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'studiotaping', 'title': 'Studio Taping'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'arts', 'title': 'Arts & Entertainment'}]",
#        "[{'alias': 'professional', 'title': 'Professional Services'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'vocalcoach', 'title': 'Vocal Coach'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'partyequipmentrentals', 'title': 'Party Equipment Rentals'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'musicinstrumentservices', 'title': 'Musical Instrument Services'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicalinstrumentsandteachers', 'title': 'Musical Instruments & Teachers'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'musicalinstrumentsandteachers', 'title': 'Musical Instruments & Teachers'}, {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'eventplanning', 'title': 'Party & Event Planning'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'djs', 'title': 'DJs'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'specialtyschools', 'title': 'Specialty Schools'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'translationservices', 'title': 'Translation Services'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'photographystores', 'title': 'Photography Stores & Services'}, {'alias': 'batterystores', 'title': 'Battery Stores'}, {'alias': 'digitizingservices', 'title': 'Digitizing Services'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'partyequipmentrentals', 'title': 'Party Equipment Rentals'}]",
#        "[{'alias': 'taxidermy', 'title': 'Taxidermy'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'audiovisualequipmentrental', 'title': 'Audio/Visual Equipment Rental'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'lighting', 'title': 'Lighting Fixtures & Equipment'}]",
#        "[{'alias': 'advertising', 'title': 'Advertising'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'engraving', 'title': 'Engraving'}, {'alias': 'productdesign', 'title': 'Product Design'}]",
#        "[{'alias': 'homewindowtinting', 'title': 'Home Window Tinting'}, {'alias': 'carwindowtinting', 'title': 'Car Window Tinting'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'musicians', 'title': 'Musicians'}]",
#        "[{'alias': 'screenprinting', 'title': 'Screen Printing'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'artclasses', 'title': 'Art Classes'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'advertising', 'title': 'Advertising'}]",
#        "[{'alias': 'petservices', 'title': 'Pet Services'}, {'alias': 'commissionedartists', 'title': 'Commissioned Artists'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'partyequipmentrentals', 'title': 'Party Equipment Rentals'}, {'alias': 'djs', 'title': 'DJs'}]",
#        "[{'alias': 'customsbrokers', 'title': 'Customs Brokers'}]",
#        "[{'alias': 'home_organization', 'title': 'Home Organization'}, {'alias': 'personalassistants', 'title': 'Personal Assistants'}]",
#        "[{'alias': 'screen_printing_tshirt_printing', 'title': 'Screen Printing/T-Shirt Printing'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'sportswear', 'title': 'Sports Wear'}]",
#        "[{'alias': 'productdesign', 'title': 'Product Design'}, {'alias': 'engraving', 'title': 'Engraving'}, {'alias': 'machineshops', 'title': 'Machine Shops'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'theater', 'title': 'Performing Arts'}, {'alias': 'talentagencies', 'title': 'Talent Agencies'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'musicians', 'title': 'Musicians'}]",
#        "[{'alias': 'accountants', 'title': 'Accountants'}, {'alias': 'payroll', 'title': 'Payroll Services'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}, {'alias': 'photographers', 'title': 'Photographers'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        '[]',
#        "[{'alias': 'professional', 'title': 'Professional Services'}]",
#        "[{'alias': 'talentagencies', 'title': 'Talent Agencies'}]",
#        "[{'alias': 'officecleaning', 'title': 'Office Cleaning'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'screenprinting', 'title': 'Screen Printing'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'lighting', 'title': 'Lighting Fixtures & Equipment'}, {'alias': 'partyequipmentrentals', 'title': 'Party Equipment Rentals'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'eventplanning', 'title': 'Party & Event Planning'}, {'alias': 'marketing', 'title': 'Marketing'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'makeupartists', 'title': 'Makeup Artists'}]",
#        "[{'alias': 'interiordesign', 'title': 'Interior Design'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photoboothrentals', 'title': 'Photo Booth Rentals'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'estatephotography', 'title': 'Real Estate Photography'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}]"],
#       dtype=object)

# %%
df_fp_ga['Categories'].unique()
# Out:
# array(["[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'arts', 'title': 'Arts & Entertainment'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'electronicsrepair', 'title': 'Electronics Repair'}]",
#        "[{'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'graphicdesign', 'title': 'Graphic Design'}]",
#        "[{'alias': 'eventplanning', 'title': 'Party & Event Planning'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}, {'alias': 'audiovisualequipmentrental', 'title': 'Audio/Visual Equipment Rental'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'dancestudio', 'title': 'Dance Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}, {'alias': 'musicproduction', 'title': 'Music Production Services'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'talentagencies', 'title': 'Talent Agencies'}]",
#        "[{'alias': 'estatephotography', 'title': 'Real Estate Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}]",
#        "[{'alias': 'eventphotography', 'title': 'Event Photography'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'web_design', 'title': 'Web Design'}]",
#        "[{'alias': 'videofilmproductions', 'title': 'Video/Film Production'}, {'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]",
#        "[{'alias': 'graphicdesign', 'title': 'Graphic Design'}, {'alias': 'fashion', 'title': 'Fashion'}, {'alias': 'screen_printing_tshirt_printing', 'title': 'Screen Printing/T-Shirt Printing'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'photographers', 'title': 'Photographers'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'marketing', 'title': 'Marketing'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        '[]',
#        "[{'alias': 'web_design', 'title': 'Web Design'}, {'alias': 'sessionphotography', 'title': 'Session Photography'}, {'alias': 'eventphotography', 'title': 'Event Photography'}]",
#        "[{'alias': 'videographers', 'title': 'Videographers'}, {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}]"],
#       dtype=object)

# %%
with open('../database/Film Production_Los Angeles_CLEAN.csv', "a") as f: 
        read_file = csv.writer(f)
        df_fp_la.to_csv('../database/Film Production_Los Angeles_CLEAN.csv', mode = "a", index = False)

# %%
with open('../database/Film Production_Atlanta_CLEAN.csv', "a") as f: 
        read_file = csv.writer(f)
        df_fp_ga.to_csv('../database/Film Production_Atlanta_CLEAN.csv', mode = "a", index = False)

# %%
with open('../database/Film Production_NYC_CLEAN.csv', "a") as f: 
        read_file = csv.writer(f)
        df_fp_ny.to_csv('../database/Film Production_NYC_CLEAN.csv', mode = "a", index = False)
