# %%
import requests
import json
import sys
import pandas as pd
import csv
from  keys  import  client_id, api_key
print(sys.path)
# Out:
# ['/Users/Mike/Flatiron_020121/yelp_phase1_project', '/opt/anaconda3/lib/python38.zip', '/opt/anaconda3/lib/python3.8', '/opt/anaconda3/lib/python3.8/lib-dynload', '', '/opt/anaconda3/lib/python3.8/site-packages', '/opt/anaconda3/lib/python3.8/site-packages/aeosa', '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/Users/Mike/.ipython']

# %%
url =  'https://api.yelp.com/v3/businesses/search' #points to url of user's yelp developer page

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }


# Dynamic: change term, location, and categories to pull different results from call
# * Required for defining url_params
term = 'Film Production'
location = 'Brooklyn'
categories = 'Video/Film'
spec = f'{term}_{location}_{categories}_data'

url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
                "offset": 0
            }

# %%
response = requests.get(url, headers=headers, params=url_params)
data = response.json()

# %%
def yelp_call(headers, url_params):
    """
    This will use the requests module to get from Yelp. 
    What is returned will be modified by our URL parameters.
    This must be called fresh with updated url_params for each call if we want to return more results.
    
    2/14 — defined data variable in this loop.
    """
    response = requests.get(url, headers=headers, params=url_params) # our url, header and params should be consistent, atleast with our Yelp data
    data = response.json()
    return data

# %%
def parse_data(list_of_data):
    """
    Input data['businesses'] to return a list of tuples,
    with each tuple containing individual business name, address, and other items
    """
    businesses = []
    for business in list_of_data:
        biz_price = None
        if 'price' not in business.keys():
            biz_price = None
        else:
            biz_price = len(business['price'])
        biz_tuple = (business['name'],
                     business['location']['display_address'],
                     business['location']['city'],
                     business['rating'],
                     business['review_count'],
                     business['coordinates'],
                     biz_price)
        businesses.append(biz_tuple)
    return businesses

# %%
current_offset = 0
url_params['offset'] = current_offset
results = yelp_call(headers, url_params)
parsed = parse_data(results['businesses'])
num = results['total']
df = pd.DataFrame(parsed, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
while current_offset < (num+50) and current_offset < 1000:     

    
#         concat or append df here
#             current_offset += 50
#             url_params['offset'] = current_offset
#             results = yelp_call(headers, url_params)
#             parsed = parse_data(results['businesses'])

        df2 = pd.DataFrame(parsed, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
        df.append(df2)
    current_offset += 50
    url_params['offset'] = current_offset
    results = yelp_call(headers, url_params)
    parsed = parse_data(results['businesses'])
return df

# %%
current_offset = 0
url_params['offset'] = current_offset
results = yelp_call(headers, url_params)
parsed = parse_data(results['businesses']) # list of businesses in tuples
num = results['total']
biz_list = []
for biz in results['businesses']:
    while current_offset < 1000:
        biz_list.extend(parsed)
        current_offset += 50
        url_params['offset'] = current_offset
        results = yelp_call(headers, url_params)
        if len(biz_list) < 1000:
            break
        else:
            continue
len(biz_list)
# Out:
# 1000

# %%
# len(biz_list) ## 1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-241-2957dbae5a95> in <module>
#       1 # len(biz_list) ## 1000!
# ----> 2 set(biz_list[0:2])
#
# TypeError: unhashable type: 'list'

# %%
yelp_call(headers, url_params)
# Out:
# {'error': {'code': 'VALIDATION_ERROR',
#   'description': 'Too many results requested, limit+offset must be <= 1000.'}}

# %%
len(biz_list)
# Out:
# 0

# %%
def get_restaurants(city, offset):
    """
    THIS IS ANOTHER APPROACH FROM GITHUB
    Make API request to Yelp to get restaurants for a city, and offset the results by an amount.

    Note that Yelp only returns 20 results each time, which is why we need to offset if we want
    the next Nth results.
    """

      """ WE HAVE THIS """
#     # Read Yelp API keys
#     with io.open('config_secret.json') as cred:
#         creds = json.load(cred)
#         auth = Oauth1Authenticator(**creds)
#         client = Client(auth)

    # Set search parameters for Yelp API request
    # Set term as restaurant to get restaurants back as the results
    # Also pass in offset, so Yelp knows how much to offset by

      """ WE HAVE THIS TOO """
    #     params = {
#         'term': 'restaurant',
#         'offset': offset
#     }

    # Make Yelp API call and return the API response
    return client.search(city, **params)

# %%
results = yelp_call(headers, url_params)
parsed = parse_data(results['businesses'])
len(parsed)
# Out:
# 50

# %%
 """ 
 THIS IS PART 2 OF ANOTHER APPROACH FROM GITHUB
 Get all restaurants for a city from Yelp and load restaurants into database.
 """

    # Get city id, as city id is a required parameter when adding a restaurant to the database
    city_id = get_city_id(city)

    # Start offset at 0 to return the first 20 results from Yelp API request
    offset = 0
    response = get_restaurants(city, offset)

    # Get total number of restaurants for this city
    total_results = response.total 
    """ 
    ^ AHA, THIS IS WHAT WE NEED FOR num IN OUR WHILE LOOP!
    
    JAKE POINTED TO THIS BUT INPUT TOTAL OF DATA VARIABLE, NOT JSON TOTAL
    
    WOULD BE EQUIVALENT TO LEN(PARSED) RIGHT AFTER DEFINING PARSED IN OUR WHILE LOOP
    
    PROBABLY DO NOT NEED IT
    ACTUALLY ENSURING THAT WE ARE NOT CALLING MORE THAN TOTAL POSSIBLE RESULTS 
    (AS JAKE WAS DOING WITH DATA['TOTAL'] IS SMART
    """

    # Offset by 20 each time to get all restaurants and load each restaurant into the database
    while offset < total_results:

        #CODE BELOW is essentially our PARSE_DATA() function
        for business in response.businesses:
            restaurant = Restaurant(city_id=city_id,
                                    name=business.name,
                                    address=" ".join(business.location.display_address),
                                    phone=business.display_phone,
                                    image_url=business.image_url,
                                    latitude=business.location.coordinate.latitude,
                                    longitude=business.location.coordinate.longitude)

            # Add each restaurant to the db
        #THIS IS WHAT WE NEED TO DO CORRECTLY
            db.session.add(restaurant)

        offset += 20

        response = get_restaurants(city, offset)

# %%
def call_1000():
    """ MIKE NOTES: 
    12/13 — I believe num should be referring to the number of 
    results that are in our dataframe or dict.
    
    12/14 — Might not be a bad idea to loop through offset BEFORE writing to a csv file.
    This could be done by offsetting, adding new to a dict, then writing to a csv file
    *afterwards outside of our while-loop*. 
    ***Persistent opening/writing to csv is messy AF***
    
    df might need to be defined BEFORE while-loop, then APPENDED or CONCAT within while-loop.
    """
    current_offset = 0
    url_params['offset'] = current_offset
    results = yelp_call(headers, url_params)
    parsed = parse_data(results['businesses'])
    num = results['total']
#     total_called = len(parsed)
    df = pd.DataFrame(parsed, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
    while current_offset < (num+50) and current_offset < 1000:     
#         concat or append df here
#             current_offset += 50
#             url_params['offset'] = current_offset
#             results = yelp_call(headers, url_params)
#             parsed = parse_data(results['businesses'])
            
            df2 = pd.DataFrame(parsed, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
            df.append(df2)
        current_offset += 50
        url_params['offset'] = current_offset
        results = yelp_call(headers, url_params)
        parsed = parse_data(results['businesses'])
    return df


#     pd.concat([df, df_2])

# df_save(csv_filepath, df)
# pd.read_csv(csv_filepath)
# Jake's suggestion, create workaround that checks to see —— 
#if ['businesses'] in data.keys():

# %%
called_1k = call_1000()

# %%
called_1k.iloc[45:60]
# Out:
#                      Name                                      Address  \
# 45  Brain Fry Productions    [2853 Steinway St, 2F, Astoria, NY 11103]
# 46      Silvercup Studios  [42-22 22nd St, Long Island City, NY 11101]
# 47          YouTube Space             [75 9th Ave, New York, NY 10011]
# 48         Sun Production       [36-06 30th St, C7, Astoria, NY 11106]
# 49        Broadway Stages    [359 Kingsland Ave, Greenpoint, NY 11222]
#
#                 City  Rating  Review Count  \
# 45           Astoria     5.0             2
# 46  Long Island City     4.5            12
# 47          New York     5.0             6
# 48           Astoria     5.0             1
# 49        Greenpoint     4.0             1
#
#                                           Coordinates  Price
# 45   {'latitude': 40.630508, 'longitude': -74.028456}    NaN
# 46   {'latitude': 40.751331, 'longitude': -73.943515}    NaN
# 47   {'latitude': 40.742581, 'longitude': -74.005434}    NaN
# 48   {'latitude': 40.756815, 'longitude': -73.930988}    NaN
# 49  {'latitude': 40.7289565103425, 'longitude': -7...    NaN

# %%
called_1k.tail()
# Out:
#                      Name                                      Address  \
# 45  Brain Fry Productions    [2853 Steinway St, 2F, Astoria, NY 11103]
# 46      Silvercup Studios  [42-22 22nd St, Long Island City, NY 11101]
# 47          YouTube Space             [75 9th Ave, New York, NY 10011]
# 48         Sun Production       [36-06 30th St, C7, Astoria, NY 11106]
# 49        Broadway Stages    [359 Kingsland Ave, Greenpoint, NY 11222]
#
#                 City  Rating  Review Count  \
# 45           Astoria     5.0             2
# 46  Long Island City     4.5            12
# 47          New York     5.0             6
# 48           Astoria     5.0             1
# 49        Greenpoint     4.0             1
#
#                                           Coordinates  Price
# 45   {'latitude': 40.630508, 'longitude': -74.028456}    NaN
# 46   {'latitude': 40.751331, 'longitude': -73.943515}    NaN
# 47   {'latitude': 40.742581, 'longitude': -74.005434}    NaN
# 48   {'latitude': 40.756815, 'longitude': -73.930988}    NaN
# 49  {'latitude': 40.7289565103425, 'longitude': -7...    NaN

# %%
test_parsed = parse_data(results['businesses'])
test_parsed
test_d = pd.DataFrame(parsed, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
test_d.append(parsed)
# Out:
#                         0                                            1  \
# 0                     NaN                                          NaN
# 1                     NaN                                          NaN
# 2                     NaN                                          NaN
# 3                     NaN                                          NaN
# 4                     NaN                                          NaN
# ..                    ...                                          ...
# 45  Brain Fry Productions    [2853 Steinway St, 2F, Astoria, NY 11103]
# 46      Silvercup Studios  [42-22 22nd St, Long Island City, NY 11101]
# 47          YouTube Space             [75 9th Ave, New York, NY 10011]
# 48         Sun Production       [36-06 30th St, C7, Astoria, NY 11106]
# 49        Broadway Stages    [359 Kingsland Ave, Greenpoint, NY 11222]
#
#                    2    3     4  \
# 0                NaN  NaN   NaN
# 1                NaN  NaN   NaN
# 2                NaN  NaN   NaN
# 3                NaN  NaN   NaN
# 4                NaN  NaN   NaN
# ..               ...  ...   ...
# 45           Astoria  5.0   2.0
# 46  Long Island City  4.5  12.0
# 47          New York  5.0   6.0
# 48           Astoria  5.0   1.0
# 49        Greenpoint  4.0   1.0
#
#                                                     5   6  \
# 0                                                 NaN NaN
# 1                                                 NaN NaN
# 2                                                 NaN NaN
# 3                                                 NaN NaN
# 4                                                 NaN NaN
# ..                                                ...  ..
# 45   {'latitude': 40.630508, 'longitude': -74.028456} NaN
# 46   {'latitude': 40.751331, 'longitude': -73.943515} NaN
# 47   {'latitude': 40.742581, 'longitude': -74.005434} NaN
# 48   {'latitude': 40.756815, 'longitude': -73.930988} NaN
# 49  {'latitude': 40.7289565103425, 'longitude': -7... NaN
#
#                                               Address      City  \
# 0   [1166 Manhattan Ave, Ste 201, Brooklyn, NY 11222]  Brooklyn
# 1           [42 West St, Ste 301, Brooklyn, NY 11222]  Brooklyn
# 2              [13 Lexington Ave, Brooklyn, NY 11238]  Brooklyn
# 3        [193 Marcus Garvey Blvd, Brooklyn, NY 11221]  Brooklyn
# 4                                [Brooklyn, NY 11231]  Brooklyn
# ..                                                ...       ...
# 45                                                NaN       NaN
# 46                                                NaN       NaN
# 47                                                NaN       NaN
# 48                                                NaN       NaN
# 49                                                NaN       NaN
#
#                                           Coordinates  \
# 0   {'latitude': 40.7382584, 'longitude': -73.9549...
# 1   {'latitude': 40.7280427, 'longitude': -73.9588...
# 2   {'latitude': 40.6866128, 'longitude': -73.9616...
# 3    {'latitude': 40.691765, 'longitude': -73.939434}
# 4   {'latitude': 40.6772802, 'longitude': -74.0094...
# ..                                                ...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                        Name  Price  Rating  Review Count
# 0                    DiJiFi    2.0     4.5         165.0
# 1                  590films    NaN     5.0           4.0
# 2     Shell's Loft Brooklyn    NaN     5.0           2.0
# 3   Mind of Who Productions    NaN     4.5           2.0
# 4     Kaleidoscope Pictures    NaN     5.0           8.0
# ..                      ...    ...     ...           ...
# 45                      NaN    NaN     NaN           NaN
# 46                      NaN    NaN     NaN           NaN
# 47                      NaN    NaN     NaN           NaN
# 48                      NaN    NaN     NaN           NaN
# 49                      NaN    NaN     NaN           NaN
#
# [100 rows x 14 columns]

# %%
# data['total']
yelp_call(headers, url_params)['total']
# Out:
# 298

# %%
# df = pd.DataFrame(parsed_results, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])

# %%
# your code to open the csv file, concat the current data, and save the data. 

def df_save(csv_filepath, df): # MIKE NOTE: an if statement for if the file exists may be useful
    with open(csv_filepath, "a") as f: #'x' creates and writes to csv
        read_file = csv.writer(f)
        df.to_csv(csv_filepath, mode = "a", index = False)
# this will append to csv. 2nd arg index=False to not save the inde

# %%
df_save(f'database/{term}_{location}_database.csv', df)

# %%
#testing call_1000() contents outside of function

current_offset = url_params['offset']
df = pd.DataFrame(data, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
num = 0
while current_offset < (num+1) and current_offset < 951: 
    url_params['offset'] = current_offset

    results = yelp_call(headers, url_params)
    parsed = parse_data(results['businesses'])
    #concat or append df here
    df_2 = pd.DataFrame(parsed, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
    df.append(df_2, ignore_index=True)
#     num += len(df)
#     current_offset += 50
#     url_params['offset'] = current_offset
    print(df, current_offset, num, url_params)
# Out:
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: [] 0 0 {'term': 'Film+Production', 'location': 'Brooklyn', 'categories': 'Video/Film', 'limit': 50, 'offset': 0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-1761612302a2> in <module>
#       4 num = 0
#       5 while current_offset < (num+1) and current_offset < 951:
# ----> 6     results = yelp_call(headers, url_params)
#       7     parsed = parse_data(results['businesses'])
#       8     #concat or append df here
#
# <ipython-input-49-b279f7f53f43> in yelp_call(headers, url_params)
#       1 def yelp_call(headers, url_params):
# ----> 2     response = requests.get(url, headers=headers, params=url_params) # our url, header and params should be consistent, atleast with our Yelp data
#       3     return response.json()
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# /opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# testing DataFrame output from parsed (parsed = parse_data(data['businesses']))

pd.DataFrame(parsed[0:3], columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
# Out:
#                     Name                                            Address  \
# 0                 DiJiFi  [1166 Manhattan Ave, Ste 201, Brooklyn, NY 11222]
# 1               590films          [42 West St, Ste 301, Brooklyn, NY 11222]
# 2  Shell's Loft Brooklyn             [13 Lexington Ave, Brooklyn, NY 11238]
#
#        City  Rating  Review Count  \
# 0  Brooklyn     4.5           165
# 1  Brooklyn     5.0             4
# 2  Brooklyn     5.0             2
#
#                                          Coordinates  Price
# 0  {'latitude': 40.7382584, 'longitude': -73.9549...    2.0
# 1  {'latitude': 40.7280427, 'longitude': -73.9588...    NaN
# 2  {'latitude': 40.6866128, 'longitude': -73.9616...    NaN

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # Tests below
# ### (first cell through yelp call must be run before these)

# %%
parsed = parse_data(data['businesses'])
parsed
# Out:
# [('DiJiFi',
#   ['1166 Manhattan Ave', 'Ste 201', 'Brooklyn, NY 11222'],
#   'Brooklyn',
#   4.5,
#   165,
#   {'latitude': 40.7382584, 'longitude': -73.9549479},
#   2),
#  ('590films',
#   ['42 West St', 'Ste 301', 'Brooklyn, NY 11222'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.7280427, 'longitude': -73.9588363},
#   None),
#  ("Shell's Loft Brooklyn",
#   ['13 Lexington Ave', 'Brooklyn, NY 11238'],
#   'Brooklyn',
#   5.0,
#   2,
#   {'latitude': 40.6866128, 'longitude': -73.9616521},
#   None),
#  ('Mind of Who Productions',
#   ['193 Marcus Garvey Blvd', 'Brooklyn, NY 11221'],
#   'Brooklyn',
#   4.5,
#   2,
#   {'latitude': 40.691765, 'longitude': -73.939434},
#   None),
#  ('Kaleidoscope Pictures',
#   ['Brooklyn, NY 11231'],
#   'Brooklyn',
#   5.0,
#   8,
#   {'latitude': 40.6772802, 'longitude': -74.0094471},
#   None),
#  ('Cinema World Studios',
#   ['220 Dupont St', 'Brooklyn, NY 11222'],
#   'Brooklyn',
#   4.5,
#   2,
#   {'latitude': 40.735954, 'longitude': -73.950508},
#   None),
#  ('Starr Street Media',
#   ['852 Rogers Ave', 'Brooklyn, NY 11226'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.64986, 'longitude': -73.95257},
#   None),
#  ('Hit and Run Productions',
#   ['65 Roebling St', 'Ste 202', 'Brooklyn, NY 11211'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.7165128, 'longitude': -73.9546435},
#   None),
#  ('BK Actors Self-Tape',
#   ['141 Flushing Ave',
#    'Bldg 77 ,Ste 1336',
#    'Brooklyn Navy Yard',
#    'Brooklyn, NY 11205'],
#   'Brooklyn',
#   5.0,
#   14,
#   {'latitude': 40.6985551, 'longitude': -73.9712029},
#   None),
#  ('Bizvidmedia Productions',
#   ['99 Wallstreet', 'New York, NY 10005'],
#   'New York',
#   5.0,
#   5,
#   {'latitude': 40.70479, 'longitude': -74.00726},
#   None),
#  ('Indigo Productions',
#   ['250 W 90th St', 'New York, NY 10024'],
#   'New York',
#   5.0,
#   5,
#   {'latitude': 40.7908706665039, 'longitude': -73.9751968383789},
#   None),
#  ('Silentface',
#   ['86 Menahan St', 'Ste 2L', 'Brooklyn, NY 11221'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.69445, 'longitude': -73.92036},
#   None),
#  ('Killer Combo Studios',
#   ['641 Classon Ave', 'Brooklyn, NY 11238'],
#   'Brooklyn',
#   5.0,
#   7,
#   {'latitude': 40.678534, 'longitude': -73.958435},
#   None),
#  ('Iris Cinematics',
#   ['121 Newark Ave', 'Ste 506', 'Jersey City, NJ 07302'],
#   'Jersey City',
#   5.0,
#   1,
#   {'latitude': 40.7199096679688, 'longitude': -74.0432891845703},
#   None),
#  ('Amy Lawday Films',
#   ['Brooklyn, NY 11238'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.67772, 'longitude': -73.96312},
#   None),
#  ('An Olivetree Production',
#   ['1350 Willoughby Ave', 'New York, NY 11237'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.7061738002948, 'longitude': -73.9202935099089},
#   None),
#  ('Steiner Studios',
#   ['15 Washington Ave', 'Brooklyn, NY 11205'],
#   'Brooklyn',
#   4.5,
#   7,
#   {'latitude': 40.6983157794782, 'longitude': -73.967696428299},
#   None),
#  ('Ground Glass Motion Picture Company',
#   ['195 Christie St', 'New York, NY 10002'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.7221489, 'longitude': -73.9923325},
#   None),
#  ('Vengo Films',
#   ['8913 4th Ave', 'Ste 5837', 'Brooklyn, NY 11209'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.620018, 'longitude': -74.0292025},
#   None),
#  ('Urban Myth Studio',
#   ['505 Johnson Ave', 'Brooklyn, NY 11237'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.708663918903, 'longitude': -73.926939086334},
#   None),
#  ('Automatic Studios',
#   ['52 Bridge St', 'Brooklyn, NY 11201'],
#   'Brooklyn',
#   4.0,
#   7,
#   {'latitude': 40.703069, 'longitude': -73.98468},
#   None),
#  ('The Cubed Effect',
#   ['New York, NY 11201'],
#   'New York',
#   5.0,
#   4,
#   {'latitude': 40.69347, 'longitude': -73.99052},
#   None),
#  ('Gee Media',
#   ['Brooklyn, NY 11225'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.66363, 'longitude': -73.95541},
#   None),
#  ('Miller/Datri Entertainment',
#   ['600 Fifth Ave', 'Fl 2', 'New York, NY 10020'],
#   'New York',
#   5.0,
#   4,
#   {'latitude': 40.758596, 'longitude': -73.9784575},
#   None),
#  ('Film Trade',
#   ['86 Verona St', 'New York, NY 11231'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.6796212181687, 'longitude': -74.0091629592533},
#   None),
#  ('Hello World Communications',
#   ['118 W 22nd St', 'Fl 2', 'New York, NY 10011'],
#   'New York',
#   5.0,
#   42,
#   {'latitude': 40.7425398, 'longitude': -73.9945521},
#   None),
#  ('RUX Media',
#   ['50 Harrison St', 'Hoboken, NJ 07030'],
#   'Hoboken',
#   5.0,
#   1,
#   {'latitude': 40.7372343, 'longitude': -74.042797},
#   None),
#  ('And/With Creative',
#   ['102 Bay Ridge Ave', 'Ste 2F', 'Brooklyn, NY 11220'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.63741, 'longitude': -74.03218},
#   None),
#  ('New York Film Shop',
#   ['437 Washington St', 'New York, NY 10013'],
#   'New York',
#   5.0,
#   3,
#   {'latitude': 40.7232895, 'longitude': -74.0101166},
#   None),
#  ('GUM Studios',
#   ['4508 2nd Ave', 'Brooklyn, NY 11232'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.65181, 'longitude': -74.0143},
#   None),
#  ('Cage Free Productions',
#   ['15 Hawthorne St', 'Ste 3B', 'Brooklyn, NY 11225'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.657474, 'longitude': -73.959732},
#   None),
#  ('Starr Street Studios',
#   ['207-A Starr St', 'Ste 3-1', 'Brooklyn, NY 11237'],
#   'Brooklyn',
#   5.0,
#   8,
#   {'latitude': 40.705122, 'longitude': -73.923457},
#   None),
#  ('The Edit Center',
#   ['168 7th St', 'Ste 314', 'Brooklyn, NY 11215'],
#   'Brooklyn',
#   5.0,
#   6,
#   {'latitude': 40.6728208, 'longitude': -73.9909742},
#   None),
#  ('Muve Media',
#   ['36 Waverly Ave', 'Brooklyn, NY 11205'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.696788, 'longitude': -73.968833},
#   None),
#  ('MRD Productions',
#   ['500 W 30th St', 'New York, NY 10001'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.75194, 'longitude': -74.00156},
#   None),
#  ('V-Productions',
#   ['469 7th Ave', 'New York, NY 10018'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.7519226, 'longitude': -73.9894887},
#   None),
#  ('Deverge Studio',
#   ['150 W 28th St', 'Ste 600', 'New York, NY 10001'],
#   'New York',
#   5.0,
#   5,
#   {'latitude': 40.74676, 'longitude': -73.99282},
#   None),
#  ('Eastern Effects',
#   ['99 9th St', 'Brooklyn, NY 11215'],
#   'Brooklyn',
#   4.5,
#   3,
#   {'latitude': 40.6734029529525, 'longitude': -73.9946415645175},
#   None),
#  ('The Self Tape Space',
#   ['W 118th St & Manhattan Ave', 'New York, NY 10026'],
#   'New York',
#   5.0,
#   13,
#   {'latitude': 40.806343, 'longitude': -73.955873},
#   None),
#  ('Tom Ragan Films',
#   ['Brooklyn, NY 11215'],
#   'Brooklyn',
#   5.0,
#   2,
#   {'latitude': 40.66889, 'longitude': -73.9819},
#   None),
#  ('Fine Art Productions',
#   ['1655 Oak Tree Rd', 'Ste 270', 'Edison, NJ 08820'],
#   'Edison',
#   4.5,
#   19,
#   {'latitude': 40.5709695115082, 'longitude': -74.340228068968},
#   None),
#  ('Hello Super Studios',
#   ['Brooklyn, NY 11206'],
#   'Brooklyn',
#   5.0,
#   9,
#   {'latitude': 40.7038917541504, 'longitude': -73.9447479248047},
#   None),
#  ('AbelCine',
#   ['Industry City', '88 35th St, Fl 4', 'Brooklyn, NY 11232'],
#   'Brooklyn',
#   3.5,
#   9,
#   {'latitude': 40.6564111, 'longitude': -74.0067047},
#   4),
#  ('Jersey Filmmaker',
#   ['Jersey City, NJ 07302'],
#   'Jersey City',
#   5.0,
#   1,
#   {'latitude': 40.7218017578125, 'longitude': -74.0449295043945},
#   None),
#  ('Latour de Force Productions',
#   ['New York, NY 10019'],
#   'New York',
#   5.0,
#   7,
#   {'latitude': 40.7645378112793, 'longitude': -73.9842376708984},
#   None),
#  ('Brain Fry Productions',
#   ['2853 Steinway St', '2F', 'Astoria, NY 11103'],
#   'Astoria',
#   5.0,
#   2,
#   {'latitude': 40.630508, 'longitude': -74.028456},
#   None),
#  ('Silvercup Studios',
#   ['42-22 22nd St', 'Long Island City, NY 11101'],
#   'Long Island City',
#   4.5,
#   12,
#   {'latitude': 40.751331, 'longitude': -73.943515},
#   None),
#  ('YouTube Space',
#   ['75 9th Ave', 'New York, NY 10011'],
#   'New York',
#   5.0,
#   6,
#   {'latitude': 40.742581, 'longitude': -74.005434},
#   None),
#  ('Sun Production',
#   ['36-06 30th St', 'C7', 'Astoria, NY 11106'],
#   'Astoria',
#   5.0,
#   1,
#   {'latitude': 40.756815, 'longitude': -73.930988},
#   None),
#  ('Broadway Stages',
#   ['359 Kingsland Ave', 'Greenpoint, NY 11222'],
#   'Greenpoint',
#   4.0,
#   1,
#   {'latitude': 40.7289565103425, 'longitude': -73.9424950629473},
#   None)]

# %%
pd.DataFrame(parsed, columns =['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
# Out:
#                                    Name  \
# 0                                DiJiFi
# 1                              590films
# 2                 Shell's Loft Brooklyn
# 3               Mind of Who Productions
# 4                 Kaleidoscope Pictures
# 5                  Cinema World Studios
# 6                    Starr Street Media
# 7               Hit and Run Productions
# 8                   BK Actors Self-Tape
# 9               Bizvidmedia Productions
# 10                   Indigo Productions
# 11                           Silentface
# 12                 Killer Combo Studios
# 13                      Iris Cinematics
# 14                     Amy Lawday Films
# 15              An Olivetree Production
# 16                      Steiner Studios
# 17  Ground Glass Motion Picture Company
# 18                          Vengo Films
# 19                    Urban Myth Studio
# 20                    Automatic Studios
# 21                     The Cubed Effect
# 22                            Gee Media
# 23           Miller/Datri Entertainment
# 24                           Film Trade
# 25           Hello World Communications
# 26                            RUX Media
# 27                    And/With Creative
# 28                   New York Film Shop
# 29                          GUM Studios
# 30                Cage Free Productions
# 31                 Starr Street Studios
# 32                      The Edit Center
# 33                           Muve Media
# 34                      MRD Productions
# 35                        V-Productions
# 36                       Deverge Studio
# 37                      Eastern Effects
# 38                  The Self Tape Space
# 39                      Tom Ragan Films
# 40                 Fine Art Productions
# 41                  Hello Super Studios
# 42                             AbelCine
# 43                     Jersey Filmmaker
# 44          Latour de Force Productions
# 45                Brain Fry Productions
# 46                    Silvercup Studios
# 47                        YouTube Space
# 48                       Sun Production
# 49                      Broadway Stages
#
#                                               Address              City  \
# 0   [1166 Manhattan Ave, Ste 201, Brooklyn, NY 11222]          Brooklyn
# 1           [42 West St, Ste 301, Brooklyn, NY 11222]          Brooklyn
# 2              [13 Lexington Ave, Brooklyn, NY 11238]          Brooklyn
# 3        [193 Marcus Garvey Blvd, Brooklyn, NY 11221]          Brooklyn
# 4                                [Brooklyn, NY 11231]          Brooklyn
# 5                 [220 Dupont St, Brooklyn, NY 11222]          Brooklyn
# 6                [852 Rogers Ave, Brooklyn, NY 11226]          Brooklyn
# 7       [65 Roebling St, Ste 202, Brooklyn, NY 11211]          Brooklyn
# 8   [141 Flushing Ave, Bldg 77 ,Ste 1336, Brooklyn...          Brooklyn
# 9                 [99 Wallstreet, New York, NY 10005]          New York
# 10                [250 W 90th St, New York, NY 10024]          New York
# 11        [86 Menahan St, Ste 2L, Brooklyn, NY 11221]          Brooklyn
# 12              [641 Classon Ave, Brooklyn, NY 11238]          Brooklyn
# 13   [121 Newark Ave, Ste 506, Jersey City, NJ 07302]       Jersey City
# 14                               [Brooklyn, NY 11238]          Brooklyn
# 15          [1350 Willoughby Ave, New York, NY 11237]          New York
# 16            [15 Washington Ave, Brooklyn, NY 11205]          Brooklyn
# 17              [195 Christie St, New York, NY 10002]          New York
# 18       [8913 4th Ave, Ste 5837, Brooklyn, NY 11209]          Brooklyn
# 19              [505 Johnson Ave, Brooklyn, NY 11237]          Brooklyn
# 20                 [52 Bridge St, Brooklyn, NY 11201]          Brooklyn
# 21                               [New York, NY 11201]          New York
# 22                               [Brooklyn, NY 11225]          Brooklyn
# 23          [600 Fifth Ave, Fl 2, New York, NY 10020]          New York
# 24                 [86 Verona St, New York, NY 11231]          New York
# 25          [118 W 22nd St, Fl 2, New York, NY 10011]          New York
# 26                [50 Harrison St, Hoboken, NJ 07030]           Hoboken
# 27    [102 Bay Ridge Ave, Ste 2F, Brooklyn, NY 11220]          Brooklyn
# 28            [437 Washington St, New York, NY 10013]          New York
# 29                 [4508 2nd Ave, Brooklyn, NY 11232]          Brooklyn
# 30      [15 Hawthorne St, Ste 3B, Brooklyn, NY 11225]          Brooklyn
# 31      [207-A Starr St, Ste 3-1, Brooklyn, NY 11237]          Brooklyn
# 32          [168 7th St, Ste 314, Brooklyn, NY 11215]          Brooklyn
# 33               [36 Waverly Ave, Brooklyn, NY 11205]          Brooklyn
# 34                [500 W 30th St, New York, NY 10001]          New York
# 35                  [469 7th Ave, New York, NY 10018]          New York
# 36       [150 W 28th St, Ste 600, New York, NY 10001]          New York
# 37                    [99 9th St, Brooklyn, NY 11215]          Brooklyn
# 38   [W 118th St & Manhattan Ave, New York, NY 10026]          New York
# 39                               [Brooklyn, NY 11215]          Brooklyn
# 40      [1655 Oak Tree Rd, Ste 270, Edison, NJ 08820]            Edison
# 41                               [Brooklyn, NY 11206]          Brooklyn
# 42  [Industry City, 88 35th St, Fl 4, Brooklyn, NY...          Brooklyn
# 43                            [Jersey City, NJ 07302]       Jersey City
# 44                               [New York, NY 10019]          New York
# 45          [2853 Steinway St, 2F, Astoria, NY 11103]           Astoria
# 46        [42-22 22nd St, Long Island City, NY 11101]  Long Island City
# 47                   [75 9th Ave, New York, NY 10011]          New York
# 48             [36-06 30th St, C7, Astoria, NY 11106]           Astoria
# 49          [359 Kingsland Ave, Greenpoint, NY 11222]        Greenpoint
#
#     Rating  Review Count                                        Coordinates  \
# 0      4.5           165  {'latitude': 40.7382584, 'longitude': -73.9549...
# 1      5.0             4  {'latitude': 40.7280427, 'longitude': -73.9588...
# 2      5.0             2  {'latitude': 40.6866128, 'longitude': -73.9616...
# 3      4.5             2   {'latitude': 40.691765, 'longitude': -73.939434}
# 4      5.0             8  {'latitude': 40.6772802, 'longitude': -74.0094...
# 5      4.5             2   {'latitude': 40.735954, 'longitude': -73.950508}
# 6      5.0             1     {'latitude': 40.64986, 'longitude': -73.95257}
# 7      5.0             4  {'latitude': 40.7165128, 'longitude': -73.9546...
# 8      5.0            14  {'latitude': 40.6985551, 'longitude': -73.9712...
# 9      5.0             5     {'latitude': 40.70479, 'longitude': -74.00726}
# 10     5.0             5  {'latitude': 40.7908706665039, 'longitude': -7...
# 11     5.0             1     {'latitude': 40.69445, 'longitude': -73.92036}
# 12     5.0             7   {'latitude': 40.678534, 'longitude': -73.958435}
# 13     5.0             1  {'latitude': 40.7199096679688, 'longitude': -7...
# 14     5.0             1     {'latitude': 40.67772, 'longitude': -73.96312}
# 15     5.0             1  {'latitude': 40.7061738002948, 'longitude': -7...
# 16     4.5             7  {'latitude': 40.6983157794782, 'longitude': -7...
# 17     5.0             1  {'latitude': 40.7221489, 'longitude': -73.9923...
# 18     5.0             1  {'latitude': 40.620018, 'longitude': -74.0292025}
# 19     5.0             4  {'latitude': 40.708663918903, 'longitude': -73...
# 20     4.0             7    {'latitude': 40.703069, 'longitude': -73.98468}
# 21     5.0             4     {'latitude': 40.69347, 'longitude': -73.99052}
# 22     5.0             4     {'latitude': 40.66363, 'longitude': -73.95541}
# 23     5.0             4  {'latitude': 40.758596, 'longitude': -73.9784575}
# 24     5.0             1  {'latitude': 40.6796212181687, 'longitude': -7...
# 25     5.0            42  {'latitude': 40.7425398, 'longitude': -73.9945...
# 26     5.0             1  {'latitude': 40.7372343, 'longitude': -74.042797}
# 27     5.0             1     {'latitude': 40.63741, 'longitude': -74.03218}
# 28     5.0             3  {'latitude': 40.7232895, 'longitude': -74.0101...
# 29     5.0             1      {'latitude': 40.65181, 'longitude': -74.0143}
# 30     5.0             1   {'latitude': 40.657474, 'longitude': -73.959732}
# 31     5.0             8   {'latitude': 40.705122, 'longitude': -73.923457}
# 32     5.0             6  {'latitude': 40.6728208, 'longitude': -73.9909...
# 33     5.0             1   {'latitude': 40.696788, 'longitude': -73.968833}
# 34     5.0             1     {'latitude': 40.75194, 'longitude': -74.00156}
# 35     5.0             1  {'latitude': 40.7519226, 'longitude': -73.9894...
# 36     5.0             5     {'latitude': 40.74676, 'longitude': -73.99282}
# 37     4.5             3  {'latitude': 40.6734029529525, 'longitude': -7...
# 38     5.0            13   {'latitude': 40.806343, 'longitude': -73.955873}
# 39     5.0             2      {'latitude': 40.66889, 'longitude': -73.9819}
# 40     4.5            19  {'latitude': 40.5709695115082, 'longitude': -7...
# 41     5.0             9  {'latitude': 40.7038917541504, 'longitude': -7...
# 42     3.5             9  {'latitude': 40.6564111, 'longitude': -74.0067...
# 43     5.0             1  {'latitude': 40.7218017578125, 'longitude': -7...
# 44     5.0             7  {'latitude': 40.7645378112793, 'longitude': -7...
# 45     5.0             2   {'latitude': 40.630508, 'longitude': -74.028456}
# 46     4.5            12   {'latitude': 40.751331, 'longitude': -73.943515}
# 47     5.0             6   {'latitude': 40.742581, 'longitude': -74.005434}
# 48     5.0             1   {'latitude': 40.756815, 'longitude': -73.930988}
# 49     4.0             1  {'latitude': 40.7289565103425, 'longitude': -7...
#
#     Price
# 0     2.0
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    4.0
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN

# %%
parsed
# Out:
# [('DiJiFi',
#   ['1166 Manhattan Ave', 'Ste 201', 'Brooklyn, NY 11222'],
#   'Brooklyn',
#   4.5,
#   165,
#   {'latitude': 40.7382584, 'longitude': -73.9549479},
#   2),
#  ('590films',
#   ['42 West St', 'Ste 301', 'Brooklyn, NY 11222'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.7280427, 'longitude': -73.9588363},
#   None),
#  ("Shell's Loft Brooklyn",
#   ['13 Lexington Ave', 'Brooklyn, NY 11238'],
#   'Brooklyn',
#   5.0,
#   2,
#   {'latitude': 40.6866128, 'longitude': -73.9616521},
#   None),
#  ('Mind of Who Productions',
#   ['193 Marcus Garvey Blvd', 'Brooklyn, NY 11221'],
#   'Brooklyn',
#   4.5,
#   2,
#   {'latitude': 40.691765, 'longitude': -73.939434},
#   None),
#  ('Kaleidoscope Pictures',
#   ['Brooklyn, NY 11231'],
#   'Brooklyn',
#   5.0,
#   8,
#   {'latitude': 40.6772802, 'longitude': -74.0094471},
#   None),
#  ('Cinema World Studios',
#   ['220 Dupont St', 'Brooklyn, NY 11222'],
#   'Brooklyn',
#   4.5,
#   2,
#   {'latitude': 40.735954, 'longitude': -73.950508},
#   None),
#  ('Starr Street Media',
#   ['852 Rogers Ave', 'Brooklyn, NY 11226'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.64986, 'longitude': -73.95257},
#   None),
#  ('Hit and Run Productions',
#   ['65 Roebling St', 'Ste 202', 'Brooklyn, NY 11211'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.7165128, 'longitude': -73.9546435},
#   None),
#  ('BK Actors Self-Tape',
#   ['141 Flushing Ave',
#    'Bldg 77 ,Ste 1336',
#    'Brooklyn Navy Yard',
#    'Brooklyn, NY 11205'],
#   'Brooklyn',
#   5.0,
#   14,
#   {'latitude': 40.6985551, 'longitude': -73.9712029},
#   None),
#  ('Bizvidmedia Productions',
#   ['99 Wallstreet', 'New York, NY 10005'],
#   'New York',
#   5.0,
#   5,
#   {'latitude': 40.70479, 'longitude': -74.00726},
#   None),
#  ('Indigo Productions',
#   ['250 W 90th St', 'New York, NY 10024'],
#   'New York',
#   5.0,
#   5,
#   {'latitude': 40.7908706665039, 'longitude': -73.9751968383789},
#   None),
#  ('Silentface',
#   ['86 Menahan St', 'Ste 2L', 'Brooklyn, NY 11221'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.69445, 'longitude': -73.92036},
#   None),
#  ('Killer Combo Studios',
#   ['641 Classon Ave', 'Brooklyn, NY 11238'],
#   'Brooklyn',
#   5.0,
#   7,
#   {'latitude': 40.678534, 'longitude': -73.958435},
#   None),
#  ('Iris Cinematics',
#   ['121 Newark Ave', 'Ste 506', 'Jersey City, NJ 07302'],
#   'Jersey City',
#   5.0,
#   1,
#   {'latitude': 40.7199096679688, 'longitude': -74.0432891845703},
#   None),
#  ('Amy Lawday Films',
#   ['Brooklyn, NY 11238'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.67772, 'longitude': -73.96312},
#   None),
#  ('An Olivetree Production',
#   ['1350 Willoughby Ave', 'New York, NY 11237'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.7061738002948, 'longitude': -73.9202935099089},
#   None),
#  ('Steiner Studios',
#   ['15 Washington Ave', 'Brooklyn, NY 11205'],
#   'Brooklyn',
#   4.5,
#   7,
#   {'latitude': 40.6983157794782, 'longitude': -73.967696428299},
#   None),
#  ('Ground Glass Motion Picture Company',
#   ['195 Christie St', 'New York, NY 10002'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.7221489, 'longitude': -73.9923325},
#   None),
#  ('Vengo Films',
#   ['8913 4th Ave', 'Ste 5837', 'Brooklyn, NY 11209'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.620018, 'longitude': -74.0292025},
#   None),
#  ('Urban Myth Studio',
#   ['505 Johnson Ave', 'Brooklyn, NY 11237'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.708663918903, 'longitude': -73.926939086334},
#   None),
#  ('Automatic Studios',
#   ['52 Bridge St', 'Brooklyn, NY 11201'],
#   'Brooklyn',
#   4.0,
#   7,
#   {'latitude': 40.703069, 'longitude': -73.98468},
#   None),
#  ('The Cubed Effect',
#   ['New York, NY 11201'],
#   'New York',
#   5.0,
#   4,
#   {'latitude': 40.69347, 'longitude': -73.99052},
#   None),
#  ('Gee Media',
#   ['Brooklyn, NY 11225'],
#   'Brooklyn',
#   5.0,
#   4,
#   {'latitude': 40.66363, 'longitude': -73.95541},
#   None),
#  ('Miller/Datri Entertainment',
#   ['600 Fifth Ave', 'Fl 2', 'New York, NY 10020'],
#   'New York',
#   5.0,
#   4,
#   {'latitude': 40.758596, 'longitude': -73.9784575},
#   None),
#  ('Film Trade',
#   ['86 Verona St', 'New York, NY 11231'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.6796212181687, 'longitude': -74.0091629592533},
#   None),
#  ('Hello World Communications',
#   ['118 W 22nd St', 'Fl 2', 'New York, NY 10011'],
#   'New York',
#   5.0,
#   42,
#   {'latitude': 40.7425398, 'longitude': -73.9945521},
#   None),
#  ('RUX Media',
#   ['50 Harrison St', 'Hoboken, NJ 07030'],
#   'Hoboken',
#   5.0,
#   1,
#   {'latitude': 40.7372343, 'longitude': -74.042797},
#   None),
#  ('And/With Creative',
#   ['102 Bay Ridge Ave', 'Ste 2F', 'Brooklyn, NY 11220'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.63741, 'longitude': -74.03218},
#   None),
#  ('New York Film Shop',
#   ['437 Washington St', 'New York, NY 10013'],
#   'New York',
#   5.0,
#   3,
#   {'latitude': 40.7232895, 'longitude': -74.0101166},
#   None),
#  ('GUM Studios',
#   ['4508 2nd Ave', 'Brooklyn, NY 11232'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.65181, 'longitude': -74.0143},
#   None),
#  ('Cage Free Productions',
#   ['15 Hawthorne St', 'Ste 3B', 'Brooklyn, NY 11225'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.657474, 'longitude': -73.959732},
#   None),
#  ('Starr Street Studios',
#   ['207-A Starr St', 'Ste 3-1', 'Brooklyn, NY 11237'],
#   'Brooklyn',
#   5.0,
#   8,
#   {'latitude': 40.705122, 'longitude': -73.923457},
#   None),
#  ('The Edit Center',
#   ['168 7th St', 'Ste 314', 'Brooklyn, NY 11215'],
#   'Brooklyn',
#   5.0,
#   6,
#   {'latitude': 40.6728208, 'longitude': -73.9909742},
#   None),
#  ('Muve Media',
#   ['36 Waverly Ave', 'Brooklyn, NY 11205'],
#   'Brooklyn',
#   5.0,
#   1,
#   {'latitude': 40.696788, 'longitude': -73.968833},
#   None),
#  ('MRD Productions',
#   ['500 W 30th St', 'New York, NY 10001'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.75194, 'longitude': -74.00156},
#   None),
#  ('V-Productions',
#   ['469 7th Ave', 'New York, NY 10018'],
#   'New York',
#   5.0,
#   1,
#   {'latitude': 40.7519226, 'longitude': -73.9894887},
#   None),
#  ('Deverge Studio',
#   ['150 W 28th St', 'Ste 600', 'New York, NY 10001'],
#   'New York',
#   5.0,
#   5,
#   {'latitude': 40.74676, 'longitude': -73.99282},
#   None),
#  ('Eastern Effects',
#   ['99 9th St', 'Brooklyn, NY 11215'],
#   'Brooklyn',
#   4.5,
#   3,
#   {'latitude': 40.6734029529525, 'longitude': -73.9946415645175},
#   None),
#  ('The Self Tape Space',
#   ['W 118th St & Manhattan Ave', 'New York, NY 10026'],
#   'New York',
#   5.0,
#   13,
#   {'latitude': 40.806343, 'longitude': -73.955873},
#   None),
#  ('Tom Ragan Films',
#   ['Brooklyn, NY 11215'],
#   'Brooklyn',
#   5.0,
#   2,
#   {'latitude': 40.66889, 'longitude': -73.9819},
#   None),
#  ('Fine Art Productions',
#   ['1655 Oak Tree Rd', 'Ste 270', 'Edison, NJ 08820'],
#   'Edison',
#   4.5,
#   19,
#   {'latitude': 40.5709695115082, 'longitude': -74.340228068968},
#   None),
#  ('Hello Super Studios',
#   ['Brooklyn, NY 11206'],
#   'Brooklyn',
#   5.0,
#   9,
#   {'latitude': 40.7038917541504, 'longitude': -73.9447479248047},
#   None),
#  ('AbelCine',
#   ['Industry City', '88 35th St, Fl 4', 'Brooklyn, NY 11232'],
#   'Brooklyn',
#   3.5,
#   9,
#   {'latitude': 40.6564111, 'longitude': -74.0067047},
#   4),
#  ('Jersey Filmmaker',
#   ['Jersey City, NJ 07302'],
#   'Jersey City',
#   5.0,
#   1,
#   {'latitude': 40.7218017578125, 'longitude': -74.0449295043945},
#   None),
#  ('Latour de Force Productions',
#   ['New York, NY 10019'],
#   'New York',
#   5.0,
#   7,
#   {'latitude': 40.7645378112793, 'longitude': -73.9842376708984},
#   None),
#  ('Brain Fry Productions',
#   ['2853 Steinway St', '2F', 'Astoria, NY 11103'],
#   'Astoria',
#   5.0,
#   2,
#   {'latitude': 40.630508, 'longitude': -74.028456},
#   None),
#  ('Silvercup Studios',
#   ['42-22 22nd St', 'Long Island City, NY 11101'],
#   'Long Island City',
#   4.5,
#   12,
#   {'latitude': 40.751331, 'longitude': -73.943515},
#   None),
#  ('YouTube Space',
#   ['75 9th Ave', 'New York, NY 10011'],
#   'New York',
#   5.0,
#   6,
#   {'latitude': 40.742581, 'longitude': -74.005434},
#   None),
#  ('Sun Production',
#   ['36-06 30th St', 'C7', 'Astoria, NY 11106'],
#   'Astoria',
#   5.0,
#   1,
#   {'latitude': 40.756815, 'longitude': -73.930988},
#   None),
#  ('Broadway Stages',
#   ['359 Kingsland Ave', 'Greenpoint, NY 11222'],
#   'Greenpoint',
#   4.0,
#   1,
#   {'latitude': 40.7289565103425, 'longitude': -73.9424950629473},
#   None)]

# %%
type(len(df))
# Out:
# int

# %%
df = pd.DataFrame(data, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
results = yelp_call(headers, url_params)
parsed = parse_data(results['businesses'])
df_2 = pd.DataFrame(parsed, columns=['Name', 'Address','City', 'Rating','Review Count','Coordinates','Price'])
df.append(df_2, ignore_index=True)
df
# Out:
# Empty DataFrame
# Columns: [Name, Address, City, Rating, Review Count, Coordinates, Price]
# Index: []
